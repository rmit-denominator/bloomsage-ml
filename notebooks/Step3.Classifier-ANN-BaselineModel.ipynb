# %% [markdown]
# # Step 3. Flower Classifier - Artificial Neural Network - Baseline Model
#
# This is a simple Artificial Neural Network with 4 hidden layers.
#
# Optimizer: `tf.keras.optimizers.Adam`
#
# According to [Tensorflow API docs](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam), Adam optimization is a stochastic gradient descent method based on adaptive estimation of first-order and second-order moments. This method is "computationally efficient, has little memory requirement, invariant to diagonal rescaling of gradients, and is well suited for problems that are large in terms of data/parameters". Thus, this is a good fit for our task of image classification, since we will generate a large amount of trainable parameters that has large computing power requirement that we aim to minimize while still ensuring our model's performance.
#
# Since our data is balanced, the metric we are using to evaluate its performance is **Accuracy** ($Accuracy = \frac{correct \; classifications}{all \; classifications}$), more specifically its [Tensorflow's CategoricalAccuracy Implementation](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/CategoricalAccuracy).
#
# Refer to the code below to see how it is set up, trained, and evaluated.
#
# Subsequent models developed will have their performance measured against this model.

# %%
# Imports and environmental setups

import os, sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam


# Custom utils functions
from utils import dataset
from utils.visualization import plot_learning_curve
from utils.visualization import visualize_16predictions
from utils.glob import TARGET_IMG_SIZE


# Reproducible results
np.random.seed(42)
tf.random.set_seed(42)

# Misc.
plt.style.use('ggplot')
model_name = 'clf-ann'
dir_raw_dataset = os.path.join('../data/raw/')
dir_train_dataset = os.path.join('../data/train/')
dir_test_dataset = os.path.join('../data/test/')
dir_log = os.path.join('../log/' + model_name)
dir_models = os.path.join('../models/')
path_model = os.path.join(dir_models + model_name)  


# Environment information
print("TF version:", tf.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# TF version: 2.12.0
# GPU is NOT AVAILABLE

# %% [markdown]
# ## 3.1. Load Dataset

# %%
df = dataset.load(dir_train_dataset)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13073 entries, 0 to 13072
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ImgPath       13073 non-null  object
#  1   FileType      13073 non-null  object
#  2   Width         13073 non-null  int64
#  3   Height        13073 non-null  int64
#  4   Ratio         13073 non-null  float64
#  5   Mode          13073 non-null  object
#  6   Bands         13073 non-null  object
#  7   Transparency  13073 non-null  bool
#  8   Animated      13073 non-null  bool
#  9   Class         13073 non-null  object
# dtypes: bool(2), float64(1), int64(2), object(5)
# memory usage: 842.7+ KB

# %%
df.sample(n=42, random_state=42)
# Out:
#                              ImgPath FileType  Width  Height  Ratio Mode  \
# 10022                Rosy/000274.jpg      jpg    256     256    1.0  RGB
# 11756                Tana/000414.jpg      jpg    256     256    1.0  RGB
# 12394                Tana/001211.jpg      jpg    256     256    1.0  RGB
# 11387               Rosy/rosy_60.jpg      jpg    256     256    1.0  RGB
# 7551   Lisianthus/lisianthus_247.jpg      jpg    256     256    1.0  RGB
# 6202   Hydrangeas/hydrangeas_187.jpg      jpg    256     256    1.0  RGB
# 5714           Hydrangeas/001008.jpg      jpg    256     256    1.0  RGB
# 7990   Lisianthus/lisianthus_761.jpg      jpg    256     256    1.0  RGB
# 12896              Tana/tana_458.jpg      jpg    256     256    1.0  RGB
# 3288        Chrysanthemum/000005.jpg      jpg    256     256    1.0  RGB
# 749                  Baby/000941.jpg      jpg    256     256    1.0  RGB
# 10619                Rosy/001019.jpg      jpg    256     256    1.0  RGB
# 3706        Chrysanthemum/000539.jpg      jpg    256     256    1.0  RGB
# 7814   Lisianthus/lisianthus_555.jpg      jpg    256     256    1.0  RGB
# 4982           Hydrangeas/000104.jpg      jpg    256     256    1.0  RGB
# 7923    Lisianthus/lisianthus_69.jpg      jpg    256     256    1.0  RGB
# 2264            Calimerio/000745.jpg      jpg    256     256    1.0  RGB
# 7770   Lisianthus/lisianthus_502.jpg      jpg    256     256    1.0  RGB
# 10129                Rosy/000402.jpg      jpg    256     256    1.0  RGB
# 7104           Lisianthus/000718.jpg      jpg    256     256    1.0  RGB
# 5561           Hydrangeas/000821.jpg      jpg    256     256    1.0  RGB
# 1217               Baby/baby_439.jpg      jpg    256     256    1.0  RGB
# 4238        Chrysanthemum/001227.jpg      jpg    256     256    1.0  RGB
# 11720                Tana/000372.jpg      jpg    256     256    1.0  RGB
# 2201            Calimerio/000670.jpg      jpg    256     256    1.0  RGB
# 12093                Tana/000834.jpg      jpg    256     256    1.0  RGB
# 9609       Pingpong/pingpong_210.jpg      jpg    256     256    1.0  RGB
# 7047           Lisianthus/000648.jpg      jpg    256     256    1.0  RGB
# 7550   Lisianthus/lisianthus_246.jpg      jpg    256     256    1.0  RGB
# 1662               Baby/baby_922.jpg      jpg    256     256    1.0  RGB
# 8992             Pingpong/001006.jpg      jpg    256     256    1.0  RGB
# 7030           Lisianthus/000630.jpg      jpg    256     256    1.0  RGB
# 99                   Baby/000131.jpg      jpg    256     256    1.0  RGB
# 9393             Pingpong/001512.jpg      jpg    256     256    1.0  RGB
# 11535                Tana/000146.jpg      jpg    256     256    1.0  RGB
# 12714              Tana/tana_255.jpg      jpg    256     256    1.0  RGB
# 2865            Calimerio/001497.jpg      jpg    256     256    1.0  RGB
# 4923           Hydrangeas/000030.jpg      jpg    256     256    1.0  RGB
# 12387                Tana/001201.jpg      jpg    256     256    1.0  RGB
# 6248   Hydrangeas/hydrangeas_243.jpg      jpg    256     256    1.0  RGB
# 9391             Pingpong/001510.jpg      jpg    256     256    1.0  RGB
# 4089        Chrysanthemum/001029.jpg      jpg    256     256    1.0  RGB
#
#        Bands  Transparency  Animated          Class
# 10022  R G B         False     False           Rosy
# 11756  R G B         False     False           Tana
# 12394  R G B         False     False           Tana
# 11387  R G B         False     False           Rosy
# 7551   R G B         False     False     Lisianthus
# 6202   R G B         False     False     Hydrangeas
# 5714   R G B         False     False     Hydrangeas
# 7990   R G B         False     False     Lisianthus
# 12896  R G B         False     False           Tana
# 3288   R G B         False     False  Chrysanthemum
# 749    R G B         False     False           Baby
# 10619  R G B         False     False           Rosy
# 3706   R G B         False     False  Chrysanthemum
# 7814   R G B         False     False     Lisianthus
# 4982   R G B         False     False     Hydrangeas
# 7923   R G B         False     False     Lisianthus
# 2264   R G B         False     False      Calimerio
# 7770   R G B         False     False     Lisianthus
# 10129  R G B         False     False           Rosy
# 7104   R G B         False     False     Lisianthus
# 5561   R G B         False     False     Hydrangeas
# 1217   R G B         False     False           Baby
# 4238   R G B         False     False  Chrysanthemum
# 11720  R G B         False     False           Tana
# 2201   R G B         False     False      Calimerio
# 12093  R G B         False     False           Tana
# 9609   R G B         False     False       Pingpong
# 7047   R G B         False     False     Lisianthus
# 7550   R G B         False     False     Lisianthus
# 1662   R G B         False     False           Baby
# 8992   R G B         False     False       Pingpong
# 7030   R G B         False     False     Lisianthus
# 99     R G B         False     False           Baby
# 9393   R G B         False     False       Pingpong
# 11535  R G B         False     False           Tana
# 12714  R G B         False     False           Tana
# 2865   R G B         False     False      Calimerio
# 4923   R G B         False     False     Hydrangeas
# 12387  R G B         False     False           Tana
# 6248   R G B         False     False     Hydrangeas
# 9391   R G B         False     False       Pingpong
# 4089   R G B         False     False  Chrysanthemum

# %%
train, val = train_test_split(df, shuffle=True, test_size=0.25, random_state=42)  # 80/20/20 - train/val/test

print(f'Train data: {train.shape[0]} samples, Validation Data: {val.shape[0]} samples.')
# Out:
# Train data: 9804 samples, Validation Data: 3269 samples.

# %% [markdown]
# ## 3.2. Model Setup and Training

# %% [markdown]
# ### 3.2.1. Hyper-parameters

# %%
# Model Parameters
BATCH_SIZE = 512
INPUT_DIM = (TARGET_IMG_SIZE, TARGET_IMG_SIZE, 3)  # RGB - 3 channels images
HIDDEN_LAYER_DIM = 128
OUTPUT_CLASSES = 8  # One-hot encoded: 8 different classes

# Training Parameters
EPOCHS = 32
LEARNING_RATE = 1e-6

# %% [markdown]
# ### 3.2.2. Model Architecture

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=INPUT_DIM),
    tf.keras.layers.Dense(HIDDEN_LAYER_DIM, activation='relu'),
    tf.keras.layers.Dense(HIDDEN_LAYER_DIM, activation='relu'),
    tf.keras.layers.Dense(HIDDEN_LAYER_DIM, activation='relu'),
    tf.keras.layers.Dense(HIDDEN_LAYER_DIM, activation='sigmoid'),
    tf.keras.layers.Dense(OUTPUT_CLASSES),
], name=model_name)

model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=['categorical_accuracy'],
)

# %%
model.summary()
# Out:
# Model: "clf-ann"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 196608)            0
#
#  dense (Dense)               (None, 128)               25165952
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 25,216,520
# Trainable params: 25,216,520
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, to_file=f'images/{model_name}-Diagram.png')

# %% [markdown]
# ### 3.2.3. Training

# %%
train['Class'] = train['Class'].astype('str')
train_datagen = ImageDataGenerator(data_format='channels_last')
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory=dir_train_dataset,
    x_col='ImgPath',
    y_col='Class',
    target_size=(TARGET_IMG_SIZE, TARGET_IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

val['Class'] = val['Class'].astype('str')
val_datagen = ImageDataGenerator(data_format='channels_last')
val_generator = val_datagen.flow_from_dataframe(
    dataframe=val,
    directory=dir_train_dataset,
    x_col='ImgPath',
    y_col='Class',
    target_size=(TARGET_IMG_SIZE, TARGET_IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)
# Out:
# Found 9804 validated image filenames belonging to 8 classes.
# Found 3269 validated image filenames belonging to 8 classes.

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=dir_log)
history = model.fit(
    train_generator, validation_data=val_generator,
    epochs=EPOCHS,
    verbose=2, callbacks=[tensorboard_callback],
)
# Out:
# Epoch 1/32
# 20/20 - 40s - loss: 2.1833 - categorical_accuracy: 0.1515 - val_loss: 2.1303 - val_categorical_accuracy: 0.1621 - 40s/epoch - 2s/step
# Epoch 2/32
# 20/20 - 26s - loss: 2.0749 - categorical_accuracy: 0.1839 - val_loss: 2.0519 - val_categorical_accuracy: 0.2117 - 26s/epoch - 1s/step
# Epoch 3/32
# 20/20 - 24s - loss: 2.0163 - categorical_accuracy: 0.2251 - val_loss: 2.0038 - val_categorical_accuracy: 0.2490 - 24s/epoch - 1s/step
# Epoch 4/32
# 20/20 - 23s - loss: 1.9786 - categorical_accuracy: 0.2583 - val_loss: 1.9776 - val_categorical_accuracy: 0.2664 - 23s/epoch - 1s/step
# Epoch 5/32
# 20/20 - 22s - loss: 1.9548 - categorical_accuracy: 0.2760 - val_loss: 1.9660 - val_categorical_accuracy: 0.2787 - 22s/epoch - 1s/step
# Epoch 6/32
# 20/20 - 22s - loss: 1.9283 - categorical_accuracy: 0.2948 - val_loss: 1.9413 - val_categorical_accuracy: 0.3001 - 22s/epoch - 1s/step
# Epoch 7/32
# 20/20 - 22s - loss: 1.9043 - categorical_accuracy: 0.3125 - val_loss: 1.9184 - val_categorical_accuracy: 0.3139 - 22s/epoch - 1s/step
# Epoch 8/32
# 20/20 - 22s - loss: 1.8809 - categorical_accuracy: 0.3376 - val_loss: 1.9050 - val_categorical_accuracy: 0.3212 - 22s/epoch - 1s/step
# Epoch 9/32
# 20/20 - 24s - loss: 1.8683 - categorical_accuracy: 0.3511 - val_loss: 1.8839 - val_categorical_accuracy: 0.3478 - 24s/epoch - 1s/step
# Epoch 10/32
# 20/20 - 22s - loss: 1.8444 - categorical_accuracy: 0.3722 - val_loss: 1.8606 - val_categorical_accuracy: 0.3649 - 22s/epoch - 1s/step
# Epoch 11/32
# 20/20 - 22s - loss: 1.8282 - categorical_accuracy: 0.3925 - val_loss: 1.8480 - val_categorical_accuracy: 0.3861 - 22s/epoch - 1s/step
# Epoch 12/32
# 20/20 - 22s - loss: 1.8106 - categorical_accuracy: 0.4126 - val_loss: 1.8340 - val_categorical_accuracy: 0.3971 - 22s/epoch - 1s/step
# Epoch 13/32
# 20/20 - 21s - loss: 1.8024 - categorical_accuracy: 0.4172 - val_loss: 1.8376 - val_categorical_accuracy: 0.4029 - 21s/epoch - 1s/step
# Epoch 14/32
# 20/20 - 23s - loss: 1.7916 - categorical_accuracy: 0.4233 - val_loss: 1.8159 - val_categorical_accuracy: 0.4212 - 23s/epoch - 1s/step
# Epoch 15/32
# 20/20 - 24s - loss: 1.7827 - categorical_accuracy: 0.4378 - val_loss: 1.8019 - val_categorical_accuracy: 0.4295 - 24s/epoch - 1s/step
# Epoch 16/32
# 20/20 - 23s - loss: 1.7667 - categorical_accuracy: 0.4495 - val_loss: 1.7972 - val_categorical_accuracy: 0.4356 - 23s/epoch - 1s/step
# Epoch 17/32
# 20/20 - 23s - loss: 1.7569 - categorical_accuracy: 0.4610 - val_loss: 1.7922 - val_categorical_accuracy: 0.4469 - 23s/epoch - 1s/step
# Epoch 18/32
# 20/20 - 23s - loss: 1.7459 - categorical_accuracy: 0.4735 - val_loss: 1.7862 - val_categorical_accuracy: 0.4491 - 23s/epoch - 1s/step
# Epoch 19/32
# 20/20 - 22s - loss: 1.7437 - categorical_accuracy: 0.4768 - val_loss: 1.7818 - val_categorical_accuracy: 0.4524 - 22s/epoch - 1s/step
# Epoch 20/32
# 20/20 - 24s - loss: 1.7412 - categorical_accuracy: 0.4819 - val_loss: 1.7786 - val_categorical_accuracy: 0.4564 - 24s/epoch - 1s/step
# Epoch 21/32
# 20/20 - 23s - loss: 1.7371 - categorical_accuracy: 0.4815 - val_loss: 1.7768 - val_categorical_accuracy: 0.4567 - 23s/epoch - 1s/step
# Epoch 22/32
# 20/20 - 24s - loss: 1.7234 - categorical_accuracy: 0.4952 - val_loss: 1.7648 - val_categorical_accuracy: 0.4729 - 24s/epoch - 1s/step
# Epoch 23/32
# 20/20 - 22s - loss: 1.7177 - categorical_accuracy: 0.5048 - val_loss: 1.7583 - val_categorical_accuracy: 0.4757 - 22s/epoch - 1s/step
# Epoch 24/32
# 20/20 - 22s - loss: 1.7123 - categorical_accuracy: 0.5101 - val_loss: 1.7630 - val_categorical_accuracy: 0.4680 - 22s/epoch - 1s/step
# Epoch 25/32
# 20/20 - 23s - loss: 1.7088 - categorical_accuracy: 0.5166 - val_loss: 1.7541 - val_categorical_accuracy: 0.4855 - 23s/epoch - 1s/step
# Epoch 26/32
# 20/20 - 22s - loss: 1.7064 - categorical_accuracy: 0.5152 - val_loss: 1.7496 - val_categorical_accuracy: 0.4913 - 22s/epoch - 1s/step
# Epoch 27/32
# 20/20 - 26s - loss: 1.6979 - categorical_accuracy: 0.5308 - val_loss: 1.7486 - val_categorical_accuracy: 0.4901 - 26s/epoch - 1s/step
# Epoch 28/32
# 20/20 - 26s - loss: 1.6954 - categorical_accuracy: 0.5312 - val_loss: 1.7421 - val_categorical_accuracy: 0.4980 - 26s/epoch - 1s/step
# Epoch 29/32
# 20/20 - 27s - loss: 1.6901 - categorical_accuracy: 0.5333 - val_loss: 1.7450 - val_categorical_accuracy: 0.4894 - 27s/epoch - 1s/step
# Epoch 30/32
# 20/20 - 24s - loss: 1.6872 - categorical_accuracy: 0.5374 - val_loss: 1.7381 - val_categorical_accuracy: 0.5023 - 24s/epoch - 1s/step
# Epoch 31/32
# 20/20 - 24s - loss: 1.6836 - categorical_accuracy: 0.5409 - val_loss: 1.7366 - val_categorical_accuracy: 0.5023 - 24s/epoch - 1s/step
# Epoch 32/32
# 20/20 - 22s - loss: 1.6808 - categorical_accuracy: 0.5428 - val_loss: 1.7344 - val_categorical_accuracy: 0.5008 - 22s/epoch - 1s/step

# %%
plot_learning_curve(
    history.history['loss'],
    history.history['val_loss'],
    history.history['categorical_accuracy'],
    history.history['val_categorical_accuracy'],
    to_file=f'images/{model_name}-LearningCurve.png'
)

# %% [markdown]
# ## 3.3. Model Performance
#
# Evaluated against test dataset in `./data/test/`

# %%
test = dataset.load(dir_test_dataset)
test['Class'] = test['Class'].astype('str')
test_datagen = ImageDataGenerator(data_format='channels_last')
test_generator = test_datagen.flow_from_dataframe(
    dataframe=test,
    directory=dir_test_dataset,
    x_col='ImgPath',
    y_col='Class',
    target_size=(TARGET_IMG_SIZE, TARGET_IMG_SIZE),
    batch_size=1,
    class_mode='categorical',
    seed=42
)
# Out:
# Found 3271 validated image filenames belonging to 8 classes.

# %%
visualize_16predictions(model, test_generator, to_file=f'images/{model_name}-16SamplePredictions.png')

# %%
model.evaluate(test_generator)
# Out:
# 3271/3271 [==============================] - 37s 11ms/step - loss: 1.7259 - categorical_accuracy: 0.5008
# [1.7258830070495605, 0.5007643103599548]

# %% [markdown]
# **☞ Observation**
#
# Our baseline classification model seems to have reached peak capacity at around $0.5$ accuracy, higher than random chance of $\frac{1}{8}=0.125$.
#
# From inspecting the test predictions, we can see that the noise (irrelevant details, different flower types in the same image, background, people, etc.) in our data has a negative effect on our accuracy.
#
# This is indicative that our model can capture some, but not all important features in the training dataset, and needs further tweaking in order to achieve higher accuracy and more resistance to noise.

# %% [markdown]
# ## 3.4. Model Exporting

# %%
model.save(path_model, overwrite = True, save_format='h5')
